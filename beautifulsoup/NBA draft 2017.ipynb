# %%
#https://en.wikipedia.org/wiki/2017_NBA_draft

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://en.wikipedia.org/wiki/2017_NBA_draft")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text,'html.parser')

# %%
body_content = soup.find('div',id = 'bodyContent')

# %%
table = body_content.find_all('table')[3]

# %%
row_name  = table.find_all(class_='sortkey') #names

# %%
names = []
for row in row_name:
    names.append(row.text)

# %%
rows = table.find_all('tr')[1:]

# %%
rounds = []
picks = []
nationalities = []
teams = []
colleges = []
for row in rows:
    cols = row.find_all('td')
    rounds.append (cols[0].text)
    picks.append (cols[1].text)
    nationalities.append(cols[4].text)
    teams.append(cols[5].text)
    colleges.append(cols[6].text)

# %%
import pandas as pd

# %%
raw_data = {'Round':rounds,
           'College':colleges,
          'Players':names,
           'Team': teams,
           'Nationality': nationalities}

test = pd.DataFrame(raw_data,index= picks)
test.columns.name = "Selection"

# %%
test
# Out:
# Selection                         College                    Nationality  \
# 1                        Washington (Fr.)                  United States
# 2                              UCLA (Fr.)                  United States
# 3                              Duke (Fr.)                  United States
# 4                            Kansas (Fr.)                  United States
# 5                          Kentucky (Fr.)                  United States
# 6                     Florida State (Fr.)                  United States
# 7                           Arizona (Fr.)                        Finland
# 8                 SIG Strasbourg (France)                    France[n 2]
# 9                          NC State (Fr.)                  United States
# 10                          Gonzaga (Fr.)                  United States
# 11                         Kentucky (Fr.)                  United States
# 12                             Duke (So.)                  United States
# ...
